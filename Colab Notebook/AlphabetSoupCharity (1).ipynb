# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drive')
csv_path = '/content/drive/MyDrive/deep-learning-challenge/Resources/charity_data.csv'

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_counts[application_counts < 1000].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[classification_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_counts[classification_counts < 2000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# Other     6062
# C1200     4837
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_numeric = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = application_numeric.drop('IS_SUCCESSFUL', axis=1)
y = application_numeric['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
scaler = StandardScaler()
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10
hidden_nodes_layer4 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, input_dim=number_input_features, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, input_dim=number_input_features, activation="relu"))


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 80)                3120
#
#  dense_3 (Dense)             (None, 30)                2430
#
#  dense_4 (Dense)             (None, 10)                310
#
# =================================================================
# Total params: 5860 (22.89 KB)
# Trainable params: 5860 (22.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
nn.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 3s 2ms/step - loss: 0.7044 - accuracy: 0.6620
# Epoch 2/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6306 - accuracy: 0.6885
# Epoch 3/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6198 - accuracy: 0.6977
# Epoch 4/200
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6098 - accuracy: 0.7029
# Epoch 5/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6768 - accuracy: 0.7030
# Epoch 6/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7005 - accuracy: 0.6988
# Epoch 7/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6969 - accuracy: 0.6987
# Epoch 8/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6999 - accuracy: 0.6994
# Epoch 9/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7327 - accuracy: 0.6911
# Epoch 10/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7232 - accuracy: 0.6921
# Epoch 11/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.7217 - accuracy: 0.6995
# Epoch 12/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.7320 - accuracy: 0.7013
# Epoch 13/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7573 - accuracy: 0.6825
# Epoch 14/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.7807 - accuracy: 0.6798
# Epoch 15/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.0128 - accuracy: 0.6673
# Epoch 16/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.0408 - accuracy: 0.6643
# Epoch 17/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.1661 - accuracy: 0.6414
# Epoch 18/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.2998 - accuracy: 0.6243
# Epoch 19/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.5277 - accuracy: 0.6111
# Epoch 20/200
# 804/804 [==============================] - 4s 5ms/step - loss: 1.5033 - accuracy: 0.6146
# Epoch 21/200
# 804/804 [==============================] - 2s 3ms/step - loss: 1.5367 - accuracy: 0.6172
# Epoch 22/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.6246 - accuracy: 0.5963
# Epoch 23/200
# 804/804 [==============================] - 2s 3ms/step - loss: 1.6298 - accuracy: 0.5954
# Epoch 24/200
# 804/804 [==============================] - 2s 3ms/step - loss: 1.6261 - accuracy: 0.5963
# Epoch 25/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.6254 - accuracy: 0.5963
# Epoch 26/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.6263 - accuracy: 0.5963
# Epoch 27/200
# 804/804 [==============================] - 2s 3ms/step - loss: 1.6261 - accuracy: 0.5963
# Epoch 28/200
# 804/804 [==============================] - 2s 3ms/step - loss: 1.6735 - accuracy: 0.5927
# Epoch 29/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.8214 - accuracy: 0.5927
# Epoch 30/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.8203 - accuracy: 0.5927
# Epoch 31/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.8203 - accuracy: 0.5930
# Epoch 32/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.8232 - accuracy: 0.5932
# Epoch 33/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.8426 - accuracy: 0.5891
# Epoch 34/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9078 - accuracy: 0.5686
# Epoch 35/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9077 - accuracy: 0.5686
# Epoch 36/200
# 804/804 [==============================] - 2s 3ms/step - loss: 1.9078 - accuracy: 0.5686
# Epoch 37/200
# 804/804 [==============================] - 2s 3ms/step - loss: 1.9079 - accuracy: 0.5686
# Epoch 38/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9078 - accuracy: 0.5687
# Epoch 39/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9083 - accuracy: 0.5685
# Epoch 40/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9078 - accuracy: 0.5686
# Epoch 41/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9077 - accuracy: 0.5686
# Epoch 42/200
# 804/804 [==============================] - 1s 2ms/step - loss: 1.9077 - accuracy: 0.5686
# Epoch 43/200
# 804/804 [==============================] - 1s 2ms/step - loss: 1.9078 - accuracy: 0.5686
# Epoch 44/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9082 - accuracy: 0.5686
# Epoch 45/200
# 804/804 [==============================] - 2s 3ms/step - loss: 1.9077 - accuracy: 0.5686
# Epoch 46/200
# 804/804 [==============================] - 3s 3ms/step - loss: 1.9078 - accuracy: 0.5686
# Epoch 47/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9079 - accuracy: 0.5686
# Epoch 48/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9078 - accuracy: 0.5686
# Epoch 49/200
# 804/804 [==============================] - 1s 2ms/step - loss: 1.9079 - accuracy: 0.5686
# Epoch 50/200
# 804/804 [==============================] - 1s 2ms/step - loss: 1.9078 - accuracy: 0.5686
# Epoch 51/200
# 804/804 [==============================] - 1s 2ms/step - loss: 1.9078 - accuracy: 0.5686
# Epoch 52/200
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9078 - accuracy: 0.5686
# Epoch 53/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0401 - accuracy: 0.5426
# Epoch 54/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 55/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 56/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 57/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 58/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 59/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 60/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0662 - accuracy: 0.5383
# Epoch 61/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 62/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 63/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 64/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 65/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 66/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 67/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 68/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 69/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 70/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 71/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 72/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 73/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 74/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 75/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 76/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 77/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 78/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 79/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 80/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 81/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 82/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 83/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 84/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 85/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 86/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 87/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 88/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 89/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 90/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 91/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 92/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 93/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 94/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 95/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 96/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 97/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 98/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 99/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 100/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 101/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 102/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 103/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 104/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 105/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 106/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 107/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 108/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 109/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 110/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 111/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 112/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 113/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 114/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 115/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 116/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 117/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 118/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 119/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 120/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 121/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0662 - accuracy: 0.5383
# Epoch 122/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 123/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0659 - accuracy: 0.5383
# Epoch 124/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 125/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 126/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 127/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 128/200
# 804/804 [==============================] - 1s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 129/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 130/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 131/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 132/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 133/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 134/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 135/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 136/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 137/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 138/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 139/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 140/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0658 - accuracy: 0.5383
# Epoch 141/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 142/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 143/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 144/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 145/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 146/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 147/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 148/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 149/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 150/200
# 804/804 [==============================] - 3s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 151/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 152/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 153/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 154/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 155/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 156/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 157/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 158/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 159/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 160/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 161/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 162/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 163/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 164/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 165/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 166/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 167/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 168/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 169/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 170/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 171/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 172/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 173/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 174/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 175/200
# 804/804 [==============================] - 3s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 176/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 177/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 178/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0659 - accuracy: 0.5383
# Epoch 179/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 180/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 181/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 182/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 183/200
# 804/804 [==============================] - 3s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 184/200
# 804/804 [==============================] - 3s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 185/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 186/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0659 - accuracy: 0.5383
# Epoch 187/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 188/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 189/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 190/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 191/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 192/200
# 804/804 [==============================] - 3s 3ms/step - loss: 2.0659 - accuracy: 0.5383
# Epoch 193/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0661 - accuracy: 0.5383
# Epoch 194/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 195/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 196/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 197/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 198/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 199/200
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0660 - accuracy: 0.5383
# Epoch 200/200
# 804/804 [==============================] - 2s 3ms/step - loss: 2.0660 - accuracy: 0.5383

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 2.0651 - accuracy: 0.5370 - 740ms/epoch - 3ms/step
# Loss: 2.0650806427001953, Accuracy: 0.5370262265205383

# %%
# Export our model to HDF5 file
nn.save('/content/drive/MyDrive/deep-learning-challenge/models/model_3/AlphabetSoupCharity_Optimization2.h5')
